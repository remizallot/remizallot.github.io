# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Collecting python-frontmatter
#   Downloading python_frontmatter-1.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: getorg in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (0.3.1)
# Requirement already satisfied: pyyaml in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from python-frontmatter) (6.0.3)
# Requirement already satisfied: geopy in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from getorg) (2.9.1)
# Requirement already satisfied: retrying in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pygithub->getorg) (2.34.2)
# Requirement already satisfied: pyjwt>=2.4.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.13.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pygithub->getorg) (4.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pygithub->getorg) (2.7.0)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (49.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.1.0)
# Requirement already satisfied: pycparser in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (2026.6.17)
# Downloading python_frontmatter-1.3.0-py3-none-any.whl (10 kB)
# Installing collected packages: python-frontmatter
# Successfully installed python-frontmatter-1.3.0
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# Identification of genes involved in Queuosine Salvage<br />Gordon Research Conference, RNA editing; Lucca (Barga), Italy Banca Del Monte Di Lucca, Via della Repubblica SR445, Giannini, Fornaci di Barga, Barga, Unione dei comuni Media Valle del Serchio, Lucca, Toscana, 55052, Italia
# Invited talk<br />Northwest University; Xi'an, China 西安市, 陕西省, 中国
# Winter Acid Fast Club meeting<br />Acid Fast Club; London, United Kingdom Greater London, England, United Kingdom
# Identification of a triacylglycerol-lipase from Brassica napus by functional proteomics<br />5th European Symposium on Plant Lipids; Gdansk, Poland Gdańsk, województwo pomorskie, Polska
# Tuberculosis: Understanding the Disease Across Scales<br />Keystone Symposium; Cape Town, South Africa Cape Town, City of Cape Town, Western Cape, 8001, South Africa
# Identification of a potential queuine salvage gene in eukaryotes<br />XXIV tRNA Conference; Olmué, Chile Olmué, Provincia de Marga Marga, Región de Valparaíso, Chile
# Department Summer research symposium Seminar<br />Manchester Metropolitan University, Department of Life Sciences; Manchester, United Kingdom Manchester, Greater Manchester, England, United Kingdom
# Invited talk<br />National University of Singapore; Singapore Singapore
# Leicester 2025 summer session of the Acid Fast Club meeting<br />Acid Fast Club; Leicester, United Kingdom Leicester, City of Leicester, England, LE1 4FB, United Kingdom
# Identification of missing enzymes and transporters involved in the synthesis and salvage of Queuosine by comparative genomics<br />EMBO Conference, Ribosome Structure and Function; Strasbourg, France Strasbourg, Bas-Rhin, Collectivité européenne d'Alsace, Grand Est, France métropolitaine, France
# Salvage of the thiamin pyrimidine moiety by plant TenA proteins lacking an active site cysteine<br />Plant Biology conference; Portland, OR, USA Portland, Multnomah County, Oregon, United States
# Similarity Networks and Genome Neighborhood Networks for function assignment<br />School of Chemistry, Cardiff University; Cardiff, United Kingdom Cardiff, Cymru / Wales, CF10 2AF, United Kingdom
# Comparative genomics for the identification of unknown genes, enzymes and transporters involved in Queuosine metabolism<br />University of Illinois at Urbana-Champaign; Urbana-Champaign, IL, USA Murphy USA, 110, South High Cross Road, Urbana, Champaign County, Illinois, 61802, United States
# Production of molecules of interest from plants in Yeast, can comparative genomics help?<br />Université François Rabelais, Tours; Tours, France Tours, Indre-et-Loire, Centre-Val de Loire, France métropolitaine, France
# Genomic enzymology web tools for functional assignment: Generating and analysing Sequence Similarity Networks and Genome Neighborhood Networks with the EFI suite<br />Institut Pasteur, Centre of Bioinformatics, Biostatistics and Integrative Biology; Paris, France Paris, Île-de-France, France métropolitaine, France
# Invited talk<br />Chinese Academy of Sciences, Institute of Microbiology; Beijing, China 北京市, 中国
# Invited Seminar<br />Shanghai Jiao Tong University Medical School; Shanghai, China 上海市, 中国
# QueI and its associated activator QueJ are non-orthologous replacement of the nitrile reductase QueF in the queuosine biosynthesis pathway<br />Gordon Research Seminar and Conference, Enzymes, Coenzymes and Metabolic Pathways; Waterville Valley, NH, USA Waterville Valley, Grafton County, New Hampshire, 03215, United States
# Invited virtual seminar for the Catalysis Innovation Consortium<br />Catalysis Innovation Consortium; Virtual, USA Beyond Business Virtual Assistants, 54, Doylestown, Bucks County, Pennsylvania, 18901, United States
# Summer 2026 meeting of the Acid Fast Club<br />Liverpool School of Tropical Medicine; Liverpool, United Kingdom Liverpool, Liverpool City Region, England, United Kingdom
# An unhandled exception occurred while processing input Singapore with message Non-successful status code 429
# An unhandled exception occurred while processing input State College, PA, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Xi'an, China with message Non-successful status code 429
# An unhandled exception occurred while processing input Manchester, United Kingdom with message Non-successful status code 429
# An unhandled exception occurred while processing input Manchester, United Kingdom with message Non-successful status code 429
# An unhandled exception occurred while processing input Waterville Valley, NH, USA with message Non-successful status code 429
# An unhandled exception occurred while processing input Manchester, United Kingdom with message Non-successful status code 429
# An unhandled exception occurred while processing input Orsay, France with message Non-successful status code 429
# An unhandled exception occurred while processing input Waterville Valley, NH, USA with message Non-successful status code 429
# Identification of missing enzymes and transporters involved in the synthesis and salvage of Queuosine by comparative genomics<br />DOE JGI User meeting, Genomics of Energy and Environment Meeting; Walnut Creek, CA, USA Walnut Creek, Contra Costa County, California, United States

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
